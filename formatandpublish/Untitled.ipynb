# %%
import xarray as xr

# %%
ds=xr.open_dataset('/home/lstam/Documents/data/output_meteorological/20230919_meteo.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (lat: 400, lon: 480)
# Coordinates:
#   * lat            (lat) float64 34.0 34.02 34.04 34.06 ... 41.94 41.96 41.98
#   * lon            (lon) float64 19.2 19.22 19.24 19.26 ... 28.74 28.76 28.78
#     time           object ...
# Data variables:
#     dom_dir        (lat, lon) int64 ...
#     dom_vel        (lat, lon) float64 ...
#     res_max        (lat, lon) float64 ...
#     dir_max        (lat, lon) float64 ...
#     max_temp       (lat, lon) float64 ...
#     min_temp       (lat, lon) float64 ...
#     mean_temp      (lat, lon) float64 ...
#     max_dew_temp   (lat, lon) float64 ...
#     min_dew_temp   (lat, lon) float64 ...
#     mean_dew_temp  (lat, lon) float64 ...
#     rain_7_days    (lat, lon) float64 ...

# %%
ds['max_dew_temp']
# Out:
# <xarray.DataArray 'max_dew_temp' (lat: 400, lon: 480)>
# [192000 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float64 34.0 34.02 34.04 34.06 ... 41.92 41.94 41.96 41.98
#   * lon      (lon) float64 19.2 19.22 19.24 19.26 ... 28.72 28.74 28.76 28.78
#     time     <U10 '2023-09-19'

# %%
ds['max_dew_temp'][34:40,56:60]
# Out:
# <xarray.DataArray 'max_dew_temp' (lat: 6, lon: 4)>
# array([[22.913232, 23.063226, 22.873224, 22.553369],
#        [23.013239, 23.013239, 22.813226, 22.583368],
#        [23.063226, 22.98324 , 22.803247, 22.706659],
#        [23.103235, 23.093225, 23.023248, 22.756677],
#        [23.143243, 23.103235, 23.043237, 22.923242],
#        [23.163232, 23.053247, 22.863245, 22.833246]])
# Coordinates:
#   * lat      (lat) float64 34.68 34.7 34.72 34.74 34.76 34.78
#   * lon      (lon) float64 20.32 20.34 20.36 20.38
#     time     <U10 '2023-09-19'

# %%
ds['max_temp'][34:40,56:60]
# Out:
# <xarray.DataArray 'max_temp' (lat: 6, lon: 4)>
# array([[25.025598, 25.015588, 25.015588, 25.015588],
#        [25.025598, 25.025598, 25.015588, 25.005609],
#        [25.035608, 25.015588, 25.015588, 25.005609],
#        [25.035608, 25.015588, 25.015588, 25.005609],
#        [25.045587, 25.025598, 25.015588, 25.015588],
#        [25.055597, 25.035608, 25.015588, 25.031854]])
# Coordinates:
#   * lat      (lat) float64 34.68 34.7 34.72 34.74 34.76 34.78
#   * lon      (lon) float64 20.32 20.34 20.36 20.38
#     time     <U10 '2023-09-19'

# %%
ds['rain_7_days'][34:40,56:60]
# Out:
# <xarray.DataArray 'rain_7_days' (lat: 6, lon: 4)>
# array([[0.07, 0.01, 0.01, 0.01],
#        [0.07, 0.01, 0.01, 0.01],
#        [0.07, 0.02, 0.  , 0.02],
#        [0.07, 0.02, 0.  , 0.04],
#        [0.06, 0.02, 0.01, 0.04],
#        [0.04, 0.03, 0.02, 0.04]])
# Coordinates:
#   * lat      (lat) float64 34.68 34.7 34.72 34.74 34.76 34.78
#   * lon      (lon) float64 20.32 20.34 20.36 20.38
#     time     <U10 '2023-09-19'
