# %%
import xarray

# %%
ds=xarray.open_dataset('/home/lstam/Documents/data/output_meteorological/20230918_meteo.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (lat: 400, lon: 480)
# Coordinates:
#   * lat            (lat) float64 34.0 34.02 34.04 34.06 ... 41.94 41.96 41.98
#   * lon            (lon) float64 19.2 19.22 19.24 19.26 ... 28.74 28.76 28.78
#     time           <U10 '2023-09-18'
# Data variables:
#     dom_dir        (lat, lon) int64 ...
#     dom_vel        (lat, lon) float64 ...
#     res_max        (lat, lon) float64 ...
#     dir_max        (lat, lon) float64 ...
#     max_temp       (lat, lon) float64 ...
#     min_temp       (lat, lon) float64 ...
#     mean_temp      (lat, lon) float64 ...
#     max_dew_temp   (lat, lon) float64 ...
#     min_dew_temp   (lat, lon) float64 ...
#     mean_dew_temp  (lat, lon) float64 ...
#     rain_7_days    (lat, lon) float64 ...

# %%
ds1=xarray.open_dataset('/home/lstam/Documents/data/output_meteorological/20230917_meteo.nc')

# %%
ds1.time
# Out:
# <xarray.DataArray 'time' ()>
# array('2023-09-17', dtype='<U10')
# Coordinates:
#     time     <U10 '2023-09-17'

# %%
dsv=xarray.open_dataset('/home/lstam/Documents/newriskmodel/formatandpublish/20220930_veg.nc')

# %%
dsv.time
# Out:
# <xarray.DataArray 'time' (time: 1)>
# array(['2022-09-30T00:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2022-09-30

# %%
ds['time']=array(['2022-09-30T00:00:00.000000000'], dtype='datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-96e27d08b1e6> in <module>
# ----> 1 ds['time']=array(['2022-09-30T00:00:00.000000000'], dtype='datetime64[ns]')
#
# NameError: name 'array' is not defined
